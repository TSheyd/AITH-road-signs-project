# %%
import os
import glob
from google.colab import drive

# %%
drive.mount('/content/drive')
path = 'drive/MyDrive/work_with_ML/RoadSigns/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Подготовка модели

# %% [markdown]
# ![image.png](attachment:864f238b-445b-4d73-a421-b9e5a587ffef.png)

# %%
# %%capture
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO(path+"base_model/yolov8n.pt")

# %%
model.info()
# Out:
# YOLOv8n summary: 225 layers, 3157200 parameters, 0 gradients, 8.9 GFLOPs
# (225, 3157200, 0, 8.8575488)

# %%
history = model.train(
    data = path+"DATA/data.yaml",
    epochs = 200,
    imgsz = 320,
    device = 0,
    patience = 30,
    batch = 256,
    save_period = 20,
    verbose = True,
    optimizer = 'Adam',
    val = True,
    lrf = 0.001
)
# Out:
# Ultralytics YOLOv8.0.210 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from google.colab import files
files.download("/content/runs")
